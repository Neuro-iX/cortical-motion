# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("/home/chbricout/Downloads/scores(3).csv", index_col=0)
df
# Out:
#             subject session generation  motion_mm  motion_binary  \
# 0    sub-HCD1856468   ses-1    gen-000   2.733328           True
# 1    sub-HCD2211932   ses-1    gen-000   1.117330           True
# 2    sub-HCD0583555   ses-1    gen-000   0.656387           True
# 3    sub-HCD1886275   ses-1    gen-000   3.497048           True
# 4    sub-HCD2715152   ses-1    gen-000   2.875743           True
# ..              ...     ...        ...        ...            ...
# 647  sub-HCD1120015   ses-1    gen-000   3.494951           True
# 648  sub-HCD1694569   ses-1    gen-000   0.577905           True
# 649  sub-HCD1948170   ses-1    gen-000   1.605224           True
# 650  sub-HCD2524751   ses-1    gen-000   1.851672           True
# 651  sub-HCD0185644   ses-1    gen-000   0.885034           True
#
#                        identifier  \
# 0    sub-HCD1856468_ses-1_gen-000
# 1    sub-HCD2211932_ses-1_gen-000
# 2    sub-HCD0583555_ses-1_gen-000
# 3    sub-HCD1886275_ses-1_gen-000
# ...

# %%
sb.histplot(df, x="motion_mm")
# Out:
# <Axes: xlabel='motion_mm', ylabel='Count'>
